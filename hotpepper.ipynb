# %%
import requests
import json

# %% [markdown]
# *オブジェクト整形表示関数*

# %%
def pretty(obj):
    print(json.dumps(obj, indent=2, ensure_ascii=False))

# %% [markdown]
# *データ取得関数*

# %%
def fetch(target, paramsOption={}):
    baseUrl = 'http://webservice.recruit.co.jp/hotpepper/'
    apiVersion = 'v1'
    defaultParams = {
        'key': 'fe9c64a5d253d6fa',
        'format': 'json'
    }
    url = f'{baseUrl}{target}/{apiVersion}'
    params = dict(defaultParams, **paramsOption)
    response = requests.get(url, params=params)
    return json.loads(response.text)

# %% [markdown]
# *大エリア（都道府県）データ取得関数*

# %%
def getLargeAreas():
    data = fetch('large_area')
    areas = []

    for datum in data['results']['large_area']:
        areas.append({
            'name': datum['name'],
            'code': datum['code']
        })

    return areas

# %% [markdown]
# *中エリアデータ取得関数*

# %%
cache_middleArea = []

# %%
def getMiddleAreas():
    global cache_middleArea

    if 0 < len(cache_middleArea):
        print('Used cache_middleArea')
        return cache_middleArea

    largeAreas = getLargeAreas()
    middleAreas = [] 

    for largeArea in largeAreas:
        data = fetch('middle_area', {'large_area': largeArea['code']})

        for datum in data['results']['middle_area']:
            middleAreas.append({
                'name': datum['name'],
                'code': datum['code'],
                'large_area': datum['large_area']
            })

    cache_middleArea = middleAreas
    return middleAreas

# %% [markdown]
# *小エリアデータ取得関数*

# %%
def getSmallAreas():
    middleAreas = getMiddleAreas()
    smallAreas = []

    for middleArea in middleAreas:
        data = fetch('small_area', {'middle_area': middleArea['code']})

        for datum in data['results']['small_area']:
            smallAreas.append({
                'name': datum['name'],
                'code': datum['code'],
                'middle_area': datum['middle_area'],
                'large_area': datum['large_area']
            })

    return smallAreas

# areaList = getSmallAreas()
pretty(len(areaList))
# Out:
# 2601

# %%
data = fetch('gourmet', {
#     'large_area': 'Z011',
    'middle_area': 'Y005',
#     'small_area': 'X005',
    'count': 1
})
pretty(data)
# Out:
# {
#   "results": {
#     "api_version": "1.26",
#     "results_returned": "1",
#     "results_start": 1,
#     "shop": [
#       {
#         "name_kana": "まじっくれすとらんあんどばーじょいあぎんざ",
#         "other_memo": "貸切の場合はプロジェクター・マイク・店内音響全て無料にてお使いいただけます。",
#         "photo": {
#           "pc": {
#             "l": "https://imgfp.hotp.jp/IMGH/05/98/P034940598/P034940598_238.jpg",
#             "m": "https://imgfp.hotp.jp/IMGH/05/98/P034940598/P034940598_168.jpg",
#             "s": "https://imgfp.hotp.jp/IMGH/05/98/P034940598/P034940598_58_s.jpg"
#           },
#           "mobile": {
#             "l": "https://imgfp.hotp.jp/IMGH/05/98/P034940598/P034940598_168.jpg",
#             "s": "https://imgfp.hotp.jp/IMGH/05/98/P034940598/P034940598_100.jpg"
#           }
#         },
#         "large_area": {
#           "name": "東京",
#           "code": "Z011"
#         },
#         "party_capacity": "74",
#         "large_service_area": {
#           "name": "関東",
#           "code": "SS10"
#         },
#         "address": "東京都中央区銀座８-２-１６ ＦＵＮＤＥＳ銀座８階",
#         "mobile_access": "新橋駅銀座口徒歩4分 銀座駅徒歩5分 有楽町駅徒歩9分",
#         "id": "J001202668",
#         "lng": "139.7596028082",
#         "course": "あり",
#         "show": "あり",
#         "parking": "なし",
#         "non_smoking": "全面禁煙",
#         "horigotatsu": "なし",
#         "name": "マジックレストラン&バー GIOIA ジョイア 銀座",
#         "genre": {
#           "name": "ダイニングバー・バル",
#           "catch": "コリドー街の中心・美食と不思議の隠れ家",
#           "code": "G002"
#         },
#         "open": "月～日、祝日、祝前日: 11:30～15:00 （料理L.O. 14:30）17:00～23:00 （料理L.O. 22:00 ドリンクL.O. 22:30）",
#         "tatami": "なし",
#         "card": "利用可",
#         "charter": "貸切可 ：50名様～74名様まで可能",
#         "wifi": "あり",
#         "sub_genre": {
#           "name": "イタリアン・フレンチ",
#           "code": "G006"
#         },
#         "shop_detail_memo": "※プロマジシャンによるテーブルマジックのサービスはDinnerTimeのみとさせて頂きます。",
#         "band": "不可",
#         "middle_area": {
#           "name": "銀座・有楽町・新橋・築地・月島",
#           "code": "Y005"
#         },
#         "lat": "35.6698566430",
#         "karaoke": "なし",
#         "logo_image": "https://imgfp.hotp.jp/IMGH/26/23/P034832623/P034832623_69.jpg",
#         "midnight": "営業していない",
#         "budget": {
#           "average": "【通常平均】6000円/【宴会平均】6000円/【ランチ平均】1000円",
#           "name": "5001～7000円",
#           "code": "B004"
#         },
#         "urls": {
#           "pc": "https://www.hotpepper.jp/strJ001202668/?vos=nhppalsa000016"
#         },
#         "lunch": "あり",
#         "english": "あり",
#         "close": "年末年始 ※2020年1月4日よりFUNDES銀座に移転致しました！東京都中央区銀座8-2-16FUNDES銀座8階までお越しください。",
#         "service_area": {
#           "name": "東京",
#           "code": "SA11"
#         },
#         "budget_memo": "",
#         "tv": "あり",
#         "private_room": "あり ：入り口のないVIP ROOM…1日1組様限定！全9品＋プライベートテーブルマジック※必ずコースでご予約ください",
#         "coupon_urls": {
#           "sp": "https://www.hotpepper.jp/strJ001202668/scoupon/?vos=nhppalsa000016",
#           "pc": "https://www.hotpepper.jp/strJ001202668/map/?vos=nhppalsa000016"
#         },
#         "small_area": {
#           "name": "銀座",
#           "code": "X005"
#         },
#         "barrier_free": "なし",
#         "wedding": "※2次会や各種サプライズ・お祝いも承っております。お気軽にお問い合わせください。",
#         "access": "地下鉄銀座線・JR「新橋」駅銀座口徒歩4分、東京メトロ「銀座」駅徒歩5分の好立地！FUNDES銀座の8階です。",
#         "child": "お子様連れOK",
#         "capacity": "74",
#         "pet": "不可",
#         "free_food": "なし",
#         "ktai_coupon": "0",
#         "station_name": "新橋",
#         "catch": "目の前でマジックショー 熟練シェフの一皿を堪能",
#         "free_drink": "あり"
#       }
#     ],
#     "results_available": 2833
#   }
# }

# %%
count = 10
offset = 101
for i in range(5):
    data = fetch('gourmet', {
    #     'large_area': 'Z011',
        'middle_area': 'Y007',
    #     'small_area': 'X005',
        'type': 'lite',
        'count': count,
        'start': offset
    })
    results_available = data['results']['results_available']
    num_shops = len(data['results']['shop'])
    print(f'i:{i}, results_available:{results_available}, num_shop:{num_shops}, offset:{offset}')
    offset += count
    if 0 < num_shops: continue
# Out:
# i:0, results_available:128, num_shop:10, offset:101
# i:1, results_available:128, num_shop:10, offset:111
# i:2, results_available:128, num_shop:8, offset:121
# i:3, results_available:128, num_shop:0, offset:131
# i:4, results_available:128, num_shop:0, offset:141
# i:5, results_available:128, num_shop:0, offset:151
# i:6, results_available:128, num_shop:0, offset:161
# i:7, results_available:128, num_shop:0, offset:171
# i:8, results_available:128, num_shop:0, offset:181
# i:9, results_available:128, num_shop:0, offset:191

# %%
data = getMiddleAreas()
pretty(data)
# Out:
# Used cache_middleArea
# [
#   {
#     "name": "銀座・有楽町・新橋・築地・月島",
#     "code": "Y005",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "水道橋・飯田橋・神楽坂",
#     "code": "Y006",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "お台場",
#     "code": "Y007",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "東京・大手町・日本橋・人形町",
#     "code": "Y010",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "四ツ谷・麹町・市ヶ谷・九段下",
#     "code": "Y013",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "上野・御徒町・浅草",
#     "code": "Y015",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "北千住・日暮里・葛飾・荒川",
#     "code": "Y016",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "錦糸町・浅草橋・両国・亀戸",
#     "code": "Y017",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "門前仲町・東陽町・木場・葛西",
#     "code": "Y018",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "神田・神保町・秋葉原・御茶ノ水",
#     "code": "Y020",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "品川･目黒･田町･浜松町･五反田",
#     "code": "Y025",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "蒲田・大森・大田区",
#     "code": "Y026",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "渋谷",
#     "code": "Y030",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "原宿・青山・表参道",
#     "code": "Y035",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "恵比寿・中目黒・代官山・広尾",
#     "code": "Y040",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "赤坂・六本木・麻布十番・西麻布",
#     "code": "Y045",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "自由が丘・田園調布",
#     "code": "Y046",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "池袋",
#     "code": "Y050",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "赤羽・王子・十条",
#     "code": "Y051",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "新宿",
#     "code": "Y055",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "新大久保・大久保",
#     "code": "Y056",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "巣鴨・大塚・駒込",
#     "code": "Y057",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "中野・高円寺・阿佐ヶ谷・方南町",
#     "code": "Y060",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "下北沢・代々木上原",
#     "code": "Y070",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "高田馬場",
#     "code": "Y072",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "池尻大橋・三軒茶屋・駒沢大学",
#     "code": "Y073",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "桜新町・用賀・二子玉川",
#     "code": "Y074",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "祐天寺・学芸大学・都立大学",
#     "code": "Y075",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "幡ヶ谷・笹塚・明大前・下高井戸",
#     "code": "Y076",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "調布・府中・千歳烏山・仙川",
#     "code": "Y077",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "経堂・千歳船橋",
#     "code": "Y078",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "祖師ヶ谷大蔵・成城学園前",
#     "code": "Y079",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "大井町･中延･旗の台･戸越･馬込",
#     "code": "Y080",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "不動前・武蔵小山",
#     "code": "Y081",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "雪が谷大塚・池上",
#     "code": "Y082",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "武蔵小金井",
#     "code": "Y083",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "国立・国分寺",
#     "code": "Y088",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "青梅・昭島・小作・青梅線沿線",
#     "code": "Y089",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "多摩センター・南大沢",
#     "code": "Y090",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "吉祥寺・荻窪・三鷹",
#     "code": "Y100",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "町田",
#     "code": "Y105",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "八王子・立川",
#     "code": "Y110",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "西武池袋線（石神井公園～秋津）",
#     "code": "Y111",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "西武新宿線(中井～田無～東村山)",
#     "code": "Y112",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "練馬・板橋・成増・江古田",
#     "code": "Y113",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "都営三田線（新板橋～西高島平）",
#     "code": "Y114",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "聖蹟桜ヶ丘・高幡不動・分倍河原",
#     "code": "Y119",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "東京都その他",
#     "code": "Y852",
#     "large_area": {
#       "name": "東京",
#       "code": "Z011"
#     }
#   },
#   {
#     "name": "武蔵小杉・元住吉・新丸子",
#     "code": "Y084",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "新横浜・綱島・菊名・鴨居",
#     "code": "Y085",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "大和・中央林間・長津田",
#     "code": "Y086",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "新百合ヶ丘・登戸",
#     "code": "Y087",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "横浜",
#     "code": "Y135",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "桜木町みなとみらい･関内･中華街",
#     "code": "Y136",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "溝の口・たまプラーザ・青葉台",
#     "code": "Y137",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "上大岡・杉田・新杉田・金沢文庫",
#     "code": "Y138",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "センター北・南、仲町台・都筑区",
#     "code": "Y139",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "川崎・鶴見",
#     "code": "Y140",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "本厚木･相模大野･海老名･伊勢原",
#     "code": "Y141",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "相模原・橋本・淵野辺",
#     "code": "Y142",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "大船・戸塚・東戸塚・保土ヶ谷",
#     "code": "Y144",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "藤沢・辻堂茅ヶ崎・平塚・湘南台",
#     "code": "Y145",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "鎌倉・江の島",
#     "code": "Y853",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "小田原・箱根・湯河原・真鶴",
#     "code": "Y854",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "横須賀中央・三浦・久里浜・汐入",
#     "code": "Y855",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "逗子・葉山",
#     "code": "Y856",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "神奈川県その他",
#     "code": "Y857",
#     "large_area": {
#       "name": "神奈川",
#       "code": "Z012"
#     }
#   },
#   {
#     "name": "大宮・さいたま新都心",
#     "code": "Y130",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "川口・西川口・蕨",
#     "code": "Y131",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "浦和・武蔵浦和",
#     "code": "Y132",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "熊谷・深谷・本庄",
#     "code": "Y133",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "東松山・坂戸",
#     "code": "Y134",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "秩父",
#     "code": "Y160",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "戸田",
#     "code": "Y161",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "上尾・北上尾・蓮田",
#     "code": "Y162",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "埼玉県その他",
#     "code": "Y163",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "所沢",
#     "code": "Y845",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "西武新宿線（航空公園～南大塚）",
#     "code": "Y846",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "東武東上線 和光市～新河岸･新座",
#     "code": "Y847",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "西武池袋線（小手指～飯能）",
#     "code": "Y860",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "川越",
#     "code": "Y861",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "春日部・越谷・草加・三郷",
#     "code": "Y862",
#     "large_area": {
#       "name": "埼玉",
#       "code": "Z013"
#     }
#   },
#   {
#     "name": "千葉・稲毛",
#     "code": "Y115",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "船橋･津田沼･市川･本八幡･中山",
#     "code": "Y120",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "南房総・館山",
#     "code": "Y121",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "千葉県その他",
#     "code": "Y122",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "柏・南柏・我孫子",
#     "code": "Y125",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "舞浜・浦安・行徳・妙典",
#     "code": "Y126",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "成田・佐倉",
#     "code": "Y127",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "海浜幕張",
#     "code": "Y128",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "蘇我・鎌取・茂原",
#     "code": "Y129",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "松戸・新松戸",
#     "code": "Y690",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "銚子・旭",
#     "code": "Y858",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "木更津・市原",
#     "code": "Y859",
#     "large_area": {
#       "name": "千葉",
#       "code": "Z014"
#     }
#   },
#   {
#     "name": "結城市",
#     "code": "Y835",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "水戸",
#     "code": "Y924",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "つくば",
#     "code": "Y925",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "日立・ひたちなか",
#     "code": "Y926",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "笠間・常陸太田・茨城県北部他",
#     "code": "Y927",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "鹿嶋・鉾田・茨城県南部他",
#     "code": "Y928",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "土浦",
#     "code": "Y969",
#     "large_area": {
#       "name": "茨城",
#       "code": "Z015"
#     }
#   },
#   {
#     "name": "宇都宮",
#     "code": "Y580",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "栃木県その他",
#     "code": "Y581",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "日光・鹿沼",
#     "code": "Y863",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "那須・塩原",
#     "code": "Y864",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "小山市・栃木市",
#     "code": "Y865",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "足利市・佐野市",
#     "code": "Y979",
#     "large_area": {
#       "name": "栃木",
#       "code": "Z016"
#     }
#   },
#   {
#     "name": "桐生市・みどり市",
#     "code": "Y843",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "館林・大泉町・邑楽町",
#     "code": "Y844",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "前橋",
#     "code": "Y929",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "草津・嬬恋",
#     "code": "Y930",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "伊香保・群馬県その他",
#     "code": "Y931",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "高崎",
#     "code": "Y966",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "伊勢崎・玉村",
#     "code": "Y967",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "太田市",
#     "code": "Y968",
#     "large_area": {
#       "name": "群馬",
#       "code": "Z017"
#     }
#   },
#   {
#     "name": "滋賀県その他",
#     "code": "Y270",
#     "large_area": {
#       "name": "滋賀",
#       "code": "Z021"
#     }
#   },
#   {
#     "name": "草津市・守山市",
#     "code": "Y271",
#     "large_area": {
#       "name": "滋賀",
#       "code": "Z021"
#     }
#   },
#   {
#     "name": "大津",
#     "code": "Y946",
#     "large_area": {
#       "name": "滋賀",
#       "code": "Z021"
#     }
#   },
#   {
#     "name": "長浜市・彦根市",
#     "code": "Y947",
#     "large_area": {
#       "name": "滋賀",
#       "code": "Z021"
#     }
#   },
#   {
#     "name": "近江八幡市・東近江市",
#     "code": "Y948",
#     "large_area": {
#       "name": "滋賀",
#       "code": "Z021"
#     }
#   },
#   {
#     "name": "烏丸御池・四条烏丸",
#     "code": "Y365",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "左京区・山科区",
#     "code": "Y430",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "北区・上京区",
#     "code": "Y431",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "河原町・木屋町",
#     "code": "Y432",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "祇園・先斗町",
#     "code": "Y433",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "四条大宮・西院・右京区・西京区",
#     "code": "Y434",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "烏丸五条・京都駅周辺",
#     "code": "Y435",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "伏見桃山・伏見区・京都市郊外",
#     "code": "Y437",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "宮津・京丹後・京都府その他",
#     "code": "Y869",
#     "large_area": {
#       "name": "京都",
#       "code": "Z022"
#     }
#   },
#   {
#     "name": "梅田",
#     "code": "Y300",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "福島・野田",
#     "code": "Y301",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "淀屋橋・本町・北浜・天満橋",
#     "code": "Y305",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "京橋・天満・天六・南森町",
#     "code": "Y310",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "心斎橋・なんば・南船場・堀江",
#     "code": "Y315",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "天王寺",
#     "code": "Y325",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "上本町・鶴橋",
#     "code": "Y326",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "針中野･長居･西田辺･西成区･住吉",
#     "code": "Y327",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "関目・千林・緑橋・深江橋",
#     "code": "Y328",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "大阪市その他",
#     "code": "Y329",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "堺・高石市・和泉市",
#     "code": "Y350",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "高槻",
#     "code": "Y355",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "茨木",
#     "code": "Y356",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "泉大津･岸和田･泉佐野･りんくう",
#     "code": "Y357",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "松原市･藤井寺市･富田林･南河内",
#     "code": "Y358",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "江坂・西中島・新大阪・十三",
#     "code": "Y360",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "東大阪市・八尾市・平野・大東市",
#     "code": "Y361",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "九条･西九条･弁天町･大正･住之江",
#     "code": "Y866",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "枚方・寝屋川・守口・門真",
#     "code": "Y867",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "大阪府その他",
#     "code": "Y868",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "箕面・池田",
#     "code": "Y998",
#     "large_area": {
#       "name": "大阪",
#       "code": "Z023"
#     }
#   },
#   {
#     "name": "神戸",
#     "code": "Y370",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "明石",
#     "code": "Y371",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "灘・東灘",
#     "code": "Y372",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "須磨・垂水・西区・兵庫・長田",
#     "code": "Y373",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "姫路",
#     "code": "Y850",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "加古川",
#     "code": "Y851",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "淡路島",
#     "code": "Y870",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "西宮・芦屋・宝塚",
#     "code": "Y871",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "城崎・豊岡",
#     "code": "Y872",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "北区・有馬温泉・三田",
#     "code": "Y873",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "尼崎",
#     "code": "Y874",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "兵庫県その他",
#     "code": "Y996",
#     "large_area": {
#       "name": "兵庫",
#       "code": "Z024"
#     }
#   },
#   {
#     "name": "奈良県その他",
#     "code": "Y290",
#     "large_area": {
#       "name": "奈良",
#       "code": "Z025"
#     }
#   },
#   {
#     "name": "奈良市",
#     "code": "Y949",
#     "large_area": {
#       "name": "奈良",
#       "code": "Z025"
#     }
#   },
#   {
#     "name": "天理市・橿原市",
#     "code": "Y950",
#     "large_area": {
#       "name": "奈良",
#       "code": "Z025"
#     }
#   },
#   {
#     "name": "大和郡山市・生駒市",
#     "code": "Y970",
#     "large_area": {
#       "name": "奈良",
#       "code": "Z025"
#     }
#   },
#   {
#     "name": "白浜・和歌山県その他",
#     "code": "Y400",
#     "large_area": {
#       "name": "和歌山",
#       "code": "Z026"
#     }
#   },
#   {
#     "name": "和歌山市",
#     "code": "Y951",
#     "large_area": {
#       "name": "和歌山",
#       "code": "Z026"
#     }
#   },
#   {
#     "name": "田辺市",
#     "code": "Y952",
#     "large_area": {
#       "name": "和歌山",
#       "code": "Z026"
#     }
#   },
#   {
#     "name": "岐阜駅周辺・柳ヶ瀬・市役所",
#     "code": "Y810",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "島・則武・正木・長良",
#     "code": "Y811",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "県庁～岐南・柳津・岐阜駅以南",
#     "code": "Y812",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "穂積・北方・大垣",
#     "code": "Y813",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "日野・芥見・各務原",
#     "code": "Y814",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "高山・中津川",
#     "code": "Y879",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "多治見・土岐",
#     "code": "Y880",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "下呂・岐阜県その他",
#     "code": "Y988",
#     "large_area": {
#       "name": "岐阜",
#       "code": "Z031"
#     }
#   },
#   {
#     "name": "静岡駅周辺・葵区・駿河区",
#     "code": "Y230",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "清水駅周辺～草薙",
#     "code": "Y231",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "浜松",
#     "code": "Y800",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "伊豆・伊東・下田",
#     "code": "Y848",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "焼津・藤枝・掛川",
#     "code": "Y849",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "熱海",
#     "code": "Y876",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "富士宮",
#     "code": "Y877",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "静岡県その他",
#     "code": "Y878",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "御殿場・富士・沼津・三島",
#     "code": "Y997",
#     "large_area": {
#       "name": "静岡",
#       "code": "Z032"
#     }
#   },
#   {
#     "name": "名古屋（名古屋駅/西区/中村区）",
#     "code": "Y200",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "栄ｷﾀ錦/伏見丸の内/泉/東桜/新栄",
#     "code": "Y205",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "栄(ミナミ)/矢場町/大須/上前津",
#     "code": "Y210",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "金山・神宮前・熱田区",
#     "code": "Y215",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "鶴舞・八事・御器所",
#     "code": "Y216",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "大曽根･千種･今池･池下･守山区",
#     "code": "Y220",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "緑区・南区・天白区・瑞穂区",
#     "code": "Y221",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "本山・覚王山・藤が丘",
#     "code": "Y222",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "豊田市",
#     "code": "Y223",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "中川区・港区",
#     "code": "Y224",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "名古屋市その他",
#     "code": "Y225",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "安城・刈谷・岡崎・知立・蒲郡",
#     "code": "Y875",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "半田・知多・碧南・西尾",
#     "code": "Y992",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "春日井・小牧・一宮・江南・瀬戸",
#     "code": "Y993",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "豊橋・豊川",
#     "code": "Y994",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "愛知県その他",
#     "code": "Y995",
#     "large_area": {
#       "name": "愛知",
#       "code": "Z033"
#     }
#   },
#   {
#     "name": "三重県その他",
#     "code": "Y280",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "伊勢",
#     "code": "Y943",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "松阪",
#     "code": "Y944",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "桑名",
#     "code": "Y945",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "四日市",
#     "code": "Y971",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "津",
#     "code": "Y989",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "鈴鹿",
#     "code": "Y990",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "鳥羽・志摩",
#     "code": "Y991",
#     "large_area": {
#       "name": "三重",
#       "code": "Z034"
#     }
#   },
#   {
#     "name": "すすきの",
#     "code": "Y500",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "室蘭・登別・白老",
#     "code": "Y501",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "富良野・その他北海道",
#     "code": "Y502",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "札幌（札幌駅・大通）",
#     "code": "Y505",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "麻生・北24条（北区・東区）",
#     "code": "Y510",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "南郷・新札幌　白石・厚別・清田",
#     "code": "Y511",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "琴似・円山公園　中央・西・手稲",
#     "code": "Y512",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "平岸・澄川（豊平区・南区）",
#     "code": "Y513",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "旭川",
#     "code": "Y530",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "函館",
#     "code": "Y883",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "小樽・千歳・苫小牧・札幌近郊",
#     "code": "Y884",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "帯広・釧路・北見・河東郡",
#     "code": "Y885",
#     "large_area": {
#       "name": "北海道",
#       "code": "Z041"
#     }
#   },
#   {
#     "name": "青森市",
#     "code": "Y910",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "弘前",
#     "code": "Y911",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "八戸",
#     "code": "Y912",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "五所川原・青森西部",
#     "code": "Y913",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "十和田・三沢・おいらせ町",
#     "code": "Y914",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "むつ市・青森東部",
#     "code": "Y977",
#     "large_area": {
#       "name": "青森",
#       "code": "Z051"
#     }
#   },
#   {
#     "name": "宮古・岩手県その他",
#     "code": "Y540",
#     "large_area": {
#       "name": "岩手",
#       "code": "Z052"
#     }
#   },
#   {
#     "name": "盛岡",
#     "code": "Y915",
#     "large_area": {
#       "name": "岩手",
#       "code": "Z052"
#     }
#   },
#   {
#     "name": "花巻・北上・奥州・一関",
#     "code": "Y916",
#     "large_area": {
#       "name": "岩手",
#       "code": "Z052"
#     }
#   },
#   {
#     "name": "仙台（仙台駅周辺）",
#     "code": "Y550",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "宮城県その他",
#     "code": "Y554",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "青葉・宮城野・若林",
#     "code": "Y555",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "仙台（国分町・一番町周辺）",
#     "code": "Y886",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "泉中央",
#     "code": "Y887",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "長町",
#     "code": "Y888",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "大崎市",
#     "code": "Y889",
#     "large_area": {
#       "name": "宮城",
#       "code": "Z053"
#     }
#   },
#   {
#     "name": "秋田市",
#     "code": "Y917",
#     "large_area": {
#       "name": "秋田",
#       "code": "Z054"
#     }
#   },
#   {
#     "name": "仙北市・秋田県北部",
#     "code": "Y918",
#     "large_area": {
#       "name": "秋田",
#       "code": "Z054"
#     }
#   },
#   {
#     "name": "横手・秋田県南部",
#     "code": "Y919",
#     "large_area": {
#       "name": "秋田",
#       "code": "Z054"
#     }
#   },
#   {
#     "name": "山形市",
#     "code": "Y920",
#     "large_area": {
#       "name": "山形",
#       "code": "Z055"
#     }
#   },
#   {
#     "name": "米沢",
#     "code": "Y921",
#     "large_area": {
#       "name": "山形",
#       "code": "Z055"
#     }
#   },
#   {
#     "name": "酒田・鶴岡",
#     "code": "Y922",
#     "large_area": {
#       "name": "山形",
#       "code": "Z055"
#     }
#   },
#   {
#     "name": "山形県その他",
#     "code": "Y923",
#     "large_area": {
#       "name": "山形",
#       "code": "Z055"
#     }
#   },
#   {
#     "name": "郡山",
#     "code": "Y570",
#     "large_area": {
#       "name": "福島",
#       "code": "Z056"
#     }
#   },
#   {
#     "name": "会津若松",
#     "code": "Y890",
#     "large_area": {
#       "name": "福島",
#       "code": "Z056"
#     }
#   },
#   {
#     "name": "喜多方",
#     "code": "Y891",
#     "large_area": {
#       "name": "福島",
#       "code": "Z056"
#     }
#   },
#   {
#     "name": "福島市",
#     "code": "Y892",
#     "large_area": {
#       "name": "福島",
#       "code": "Z056"
#     }
#   },
#   {
#     "name": "いわき・福島県その他",
#     "code": "Y893",
#     "large_area": {
#       "name": "福島",
#       "code": "Z056"
#     }
#   },
#   {
#     "name": "新潟駅・万代",
#     "code": "Y820",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "新潟駅南",
#     "code": "Y821",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "古町周辺",
#     "code": "Y822",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "新潟東区・北区エリア",
#     "code": "Y823",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "新潟西エリア",
#     "code": "Y824",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "出来島･女池･桜木･鳥屋野潟周辺",
#     "code": "Y825",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "上越",
#     "code": "Y826",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "新発田",
#     "code": "Y827",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "佐渡・新潟県その他",
#     "code": "Y828",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "亀田・新津エリア",
#     "code": "Y829",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "長岡",
#     "code": "Y830",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "燕三条",
#     "code": "Y881",
#     "large_area": {
#       "name": "新潟",
#       "code": "Z061"
#     }
#   },
#   {
#     "name": "黒部・富山県その他",
#     "code": "Y831",
#     "large_area": {
#       "name": "富山",
#       "code": "Z062"
#     }
#   },
#   {
#     "name": "富山市",
#     "code": "Y932",
#     "large_area": {
#       "name": "富山",
#       "code": "Z062"
#     }
#   },
#   {
#     "name": "高岡",
#     "code": "Y933",
#     "large_area": {
#       "name": "富山",
#       "code": "Z062"
#     }
#   },
#   {
#     "name": "金沢(片町･香林坊･にし茶屋周辺)",
#     "code": "Y840",
#     "large_area": {
#       "name": "石川",
#       "code": "Z063"
#     }
#   },
#   {
#     "name": "金沢(金沢駅･近江町･ひがし茶屋)",
#     "code": "Y841",
#     "large_area": {
#       "name": "石川",
#       "code": "Z063"
#     }
#   },
#   {
#     "name": "金沢市他・野々市・白山・内灘",
#     "code": "Y842",
#     "large_area": {
#       "name": "石川",
#       "code": "Z063"
#     }
#   },
#   {
#     "name": "輪島・七尾・加賀・石川県その他",
#     "code": "Y882",
#     "large_area": {
#       "name": "石川",
#       "code": "Z063"
#     }
#   },
#   {
#     "name": "小浜・福井県その他",
#     "code": "Y816",
#     "large_area": {
#       "name": "福井",
#       "code": "Z064"
#     }
#   },
#   {
#     "name": "福井市",
#     "code": "Y934",
#     "large_area": {
#       "name": "福井",
#       "code": "Z064"
#     }
#   },
#   {
#     "name": "敦賀",
#     "code": "Y935",
#     "large_area": {
#       "name": "福井",
#       "code": "Z064"
#     }
#   },
#   {
#     "name": "坂井市",
#     "code": "Y972",
#     "large_area": {
#       "name": "福井",
#       "code": "Z064"
#     }
#   },
#   {
#     "name": "笛吹市",
#     "code": "Y796",
#     "large_area": {
#       "name": "山梨",
#       "code": "Z065"
#     }
#   },
#   {
#     "name": "富士吉田・河口湖",
#     "code": "Y936",
#     "large_area": {
#       "name": "山梨",
#       "code": "Z065"
#     }
#   },
#   {
#     "name": "北杜市",
#     "code": "Y937",
#     "large_area": {
#       "name": "山梨",
#       "code": "Z065"
#     }
#   },
#   {
#     "name": "山梨県その他",
#     "code": "Y938",
#     "large_area": {
#       "name": "山梨",
#       "code": "Z065"
#     }
#   },
#   {
#     "name": "甲府",
#     "code": "Y973",
#     "large_area": {
#       "name": "山梨",
#       "code": "Z065"
#     }
#   },
#   {
#     "name": "安曇野",
#     "code": "Y806",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "諏訪・茅野",
#     "code": "Y807",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "長野県その他",
#     "code": "Y808",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "長野市",
#     "code": "Y939",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "松本市",
#     "code": "Y940",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "軽井沢",
#     "code": "Y941",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "上田・佐久",
#     "code": "Y942",
#     "large_area": {
#       "name": "長野",
#       "code": "Z066"
#     }
#   },
#   {
#     "name": "鳥取県その他",
#     "code": "Y250",
#     "large_area": {
#       "name": "鳥取",
#       "code": "Z071"
#     }
#   },
#   {
#     "name": "鳥取市",
#     "code": "Y953",
#     "large_area": {
#       "name": "鳥取",
#       "code": "Z071"
#     }
#   },
#   {
#     "name": "米子市",
#     "code": "Y954",
#     "large_area": {
#       "name": "鳥取",
#       "code": "Z071"
#     }
#   },
#   {
#     "name": "島根県その他",
#     "code": "Y260",
#     "large_area": {
#       "name": "島根",
#       "code": "Z072"
#     }
#   },
#   {
#     "name": "松江",
#     "code": "Y955",
#     "large_area": {
#       "name": "島根",
#       "code": "Z072"
#     }
#   },
#   {
#     "name": "出雲市",
#     "code": "Y956",
#     "large_area": {
#       "name": "島根",
#       "code": "Z072"
#     }
#   },
#   {
#     "name": "岡山市",
#     "code": "Y610",
#     "large_area": {
#       "name": "岡山",
#       "code": "Z073"
#     }
#   },
#   {
#     "name": "倉敷（倉敷市中心部）",
#     "code": "Y611",
#     "large_area": {
#       "name": "岡山",
#       "code": "Z073"
#     }
#   },
#   {
#     "name": "倉敷(倉敷市郊外･児島･水島など)",
#     "code": "Y612",
#     "large_area": {
#       "name": "岡山",
#       "code": "Z073"
#     }
#   },
#   {
#     "name": "備前・岡山県その他",
#     "code": "Y895",
#     "large_area": {
#       "name": "岡山",
#       "code": "Z073"
#     }
#   },
#   {
#     "name": "広島市（広島市中心部）",
#     "code": "Y600",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "広島駅・横川・その他広島市内",
#     "code": "Y605",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "福山",
#     "code": "Y620",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "尾道",
#     "code": "Y894",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "呉",
#     "code": "Y986",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "広島県その他",
#     "code": "Y987",
#     "large_area": {
#       "name": "広島",
#       "code": "Z074"
#     }
#   },
#   {
#     "name": "萩・山口県その他",
#     "code": "Y640",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "下関",
#     "code": "Y957",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "山口市",
#     "code": "Y958",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "宇部市",
#     "code": "Y982",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "周南市・下松市",
#     "code": "Y983",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "岩国",
#     "code": "Y984",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "防府",
#     "code": "Y985",
#     "large_area": {
#       "name": "山口",
#       "code": "Z075"
#     }
#   },
#   {
#     "name": "徳島市・徳島市周辺部",
#     "code": "Y660",
#     "large_area": {
#       "name": "徳島",
#       "code": "Z081"
#     }
#   },
#   {
#     "name": "徳島県その他",
#     "code": "Y897",
#     "large_area": {
#       "name": "徳島",
#       "code": "Z081"
#     }
#   },
#   {
#     "name": "高松市中心部",
#     "code": "Y650",
#     "large_area": {
#       "name": "香川",
#       "code": "Z082"
#     }
#   },
#   {
#     "name": "高松市郊外",
#     "code": "Y652",
#     "large_area": {
#       "name": "香川",
#       "code": "Z082"
#     }
#   },
#   {
#     "name": "丸亀･坂出･宇多津･善通寺･多度津",
#     "code": "Y896",
#     "large_area": {
#       "name": "香川",
#       "code": "Z082"
#     }
#   },
#   {
#     "name": "坂出・香川県その他",
#     "code": "Y981",
#     "large_area": {
#       "name": "香川",
#       "code": "Z082"
#     }
#   },
#   {
#     "name": "松山",
#     "code": "Y670",
#     "large_area": {
#       "name": "愛媛",
#       "code": "Z083"
#     }
#   },
#   {
#     "name": "今治",
#     "code": "Y898",
#     "large_area": {
#       "name": "愛媛",
#       "code": "Z083"
#     }
#   },
#   {
#     "name": "宇和島･東予･南予･愛媛県その他",
#     "code": "Y975",
#     "large_area": {
#       "name": "愛媛",
#       "code": "Z083"
#     }
#   },
#   {
#     "name": "新居浜・西条",
#     "code": "Y980",
#     "large_area": {
#       "name": "愛媛",
#       "code": "Z083"
#     }
#   },
#   {
#     "name": "高知市",
#     "code": "Y680",
#     "large_area": {
#       "name": "高知",
#       "code": "Z084"
#     }
#   },
#   {
#     "name": "高知県その他",
#     "code": "Y899",
#     "large_area": {
#       "name": "高知",
#       "code": "Z084"
#     }
#   },
#   {
#     "name": "博多",
#     "code": "Y700",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "中洲・中洲川端",
#     "code": "Y705",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "天神・西中洲・春吉",
#     "code": "Y706",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "西新・姪浜・その他西エリア",
#     "code": "Y710",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "吉塚・香椎・その他東エリア",
#     "code": "Y711",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "大名・今泉・警固",
#     "code": "Y712",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "薬院･平尾･高砂",
#     "code": "Y713",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "大橋･その他南地区",
#     "code": "Y714",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "北九州（小倉・門司）",
#     "code": "Y730",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "北九州（八幡・黒崎・折尾）",
#     "code": "Y731",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "飯塚・筑紫野",
#     "code": "Y732",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "久留米",
#     "code": "Y900",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "福岡県その他",
#     "code": "Y901",
#     "large_area": {
#       "name": "福岡",
#       "code": "Z091"
#     }
#   },
#   {
#     "name": "佐賀市",
#     "code": "Y959",
#     "large_area": {
#       "name": "佐賀",
#       "code": "Z092"
#     }
#   },
#   {
#     "name": "佐賀県その他",
#     "code": "Y960",
#     "large_area": {
#       "name": "佐賀",
#       "code": "Z092"
#     }
#   },
#   {
#     "name": "唐津",
#     "code": "Y974",
#     "large_area": {
#       "name": "佐賀",
#       "code": "Z092"
#     }
#   },
#   {
#     "name": "長崎市",
#     "code": "Y740",
#     "large_area": {
#       "name": "長崎",
#       "code": "Z093"
#     }
#   },
#   {
#     "name": "佐世保・長崎県その他",
#     "code": "Y741",
#     "large_area": {
#       "name": "長崎",
#       "code": "Z093"
#     }
#   },
#   {
#     "name": "大村市・諫早市",
#     "code": "Y902",
#     "large_area": {
#       "name": "長崎",
#       "code": "Z093"
#     }
#   },
#   {
#     "name": "熊本市(上通り･下通り･新市街)",
#     "code": "Y760",
#     "large_area": {
#       "name": "熊本",
#       "code": "Z094"
#     }
#   },
#   {
#     "name": "熊本市郊外",
#     "code": "Y762",
#     "large_area": {
#       "name": "熊本",
#       "code": "Z094"
#     }
#   },
#   {
#     "name": "八代",
#     "code": "Y763",
#     "large_area": {
#       "name": "熊本",
#       "code": "Z094"
#     }
#   },
#   {
#     "name": "阿蘇",
#     "code": "Y905",
#     "large_area": {
#       "name": "熊本",
#       "code": "Z094"
#     }
#   },
#   {
#     "name": "天草・熊本県その他",
#     "code": "Y906",
#     "large_area": {
#       "name": "熊本",
#       "code": "Z094"
#     }
#   },
#   {
#     "name": "大分市",
#     "code": "Y750",
#     "large_area": {
#       "name": "大分",
#       "code": "Z095"
#     }
#   },
#   {
#     "name": "湯布院・由布市",
#     "code": "Y751",
#     "large_area": {
#       "name": "大分",
#       "code": "Z095"
#     }
#   },
#   {
#     "name": "大分県その他",
#     "code": "Y752",
#     "large_area": {
#       "name": "大分",
#       "code": "Z095"
#     }
#   },
#   {
#     "name": "別府",
#     "code": "Y903",
#     "large_area": {
#       "name": "大分",
#       "code": "Z095"
#     }
#   },
#   {
#     "name": "中津市",
#     "code": "Y904",
#     "large_area": {
#       "name": "大分",
#       "code": "Z095"
#     }
#   },
#   {
#     "name": "宮崎市中心部",
#     "code": "Y770",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "都城市",
#     "code": "Y771",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "宮崎県その他",
#     "code": "Y772",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "宮崎市郊外",
#     "code": "Y773",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "日南市",
#     "code": "Y777",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "延岡市・日向市",
#     "code": "Y907",
#     "large_area": {
#       "name": "宮崎",
#       "code": "Z096"
#     }
#   },
#   {
#     "name": "鹿児島市　天文館・中央駅・ふ頭",
#     "code": "Y780",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "鹿児島県その他",
#     "code": "Y781",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "騎射場・与次郎",
#     "code": "Y785",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "谷山・宇宿",
#     "code": "Y786",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "鹿児島市その他",
#     "code": "Y787",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "奄美・屋久島",
#     "code": "Y908",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "霧島市",
#     "code": "Y909",
#     "large_area": {
#       "name": "鹿児島",
#       "code": "Z097"
#     }
#   },
#   {
#     "name": "那覇",
#     "code": "Y961",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   },
#   {
#     "name": "糸満・豊見城・南風原・南城",
#     "code": "Y962",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   },
#   {
#     "name": "石垣島・宮古島・沖縄離島",
#     "code": "Y963",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   },
#   {
#     "name": "名護・恩納村・本部町",
#     "code": "Y964",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   },
#   {
#     "name": "読谷･北谷･宜野湾･浦添･嘉手納",
#     "code": "Y965",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   },
#   {
#     "name": "沖縄市・うるま・西原・北中城",
#     "code": "Y976",
#     "large_area": {
#       "name": "沖縄",
#       "code": "Z098"
#     }
#   }
# ]

# %% [markdown]
# ### 店舗情報を取得

# %%
def formatRestaurantData(data):
    return {
        'name': data['name'],
        'address': data['address'],
        'large_area': data['large_area']['name'],
        'middle_area': data['middle_area']['name'],
        'small_area': data['small_area']['name'],
        'genre': data['genre']['name'],
        'budget': data['budget']['name']
    }


def getRestaurants():
    middleAreas = getMiddleAreas()
    restaurants = []
    count = 1

    for middleArea in middleAreas:
        offset = 2831
        while True:
            data = fetch('gourmet', {
                'middle_area': middleArea['code'],
                'order': 3,  # 小エリアコード順
                'count': count,
                'start': offset
            })

            restaurantsData = data['results']['shop']

            print(f"available:{data['results']['results_available']}, offset:{offset}, num_shop:{len(restaurantsData)}")
            if len(restaurantsData) == 0: break

            for data in restaurantsData:
                restaurants.append(formatRestaurantData(data))

            offset += count
        break

    return restaurants

# %%
getRestaurants()
# Out:
# Used cache_middleArea
# results_available:2833, offset:2831, num_shop:1
# results_available:2833, offset:2832, num_shop:1
# results_available:2833, offset:2833, num_shop:1
# results_available:2833, offset:2834, num_shop:0
# [{'name': 'てんまり 天舞利',
#   'address': '東京都千代田区内幸町２‐２‐２\u3000（日比谷シティ）',
#   'large_area': '東京',
#   'middle_area': '銀座・有楽町・新橋・築地・月島',
#   'small_area': '内幸町',
#   'genre': '和食',
#   'budget': '3001～4000円'},
#  {'name': '帝国ホテル東京 パークサイドダイナー',
#   'address': '東京都千代田区内幸町１‐１‐１\u3000帝国ホテル東京 本館１Ｆ',
#   'large_area': '東京',
#   'middle_area': '銀座・有楽町・新橋・築地・月島',
#   'small_area': '内幸町',
#   'genre': '洋食',
#   'budget': '4001～5000円'},
#  {'name': 'ランデブーラウンジ・バー 帝国ホテル東京',
#   'address': '東京都千代田区内幸町１‐１‐１\u3000帝国ホテル東京 本館１Ｆ',
#   'large_area': '東京',
#   'middle_area': '銀座・有楽町・新橋・築地・月島',
#   'small_area': '内幸町',
#   'genre': 'バー・カクテル',
#   'budget': '2001～3000円'}]
